# %% [markdown]
# <a href="https://colab.research.google.com/github/dkavali/data690_Dikshitha/blob/main/assignment_05/assignment_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment-05

# %% [markdown]
# #### 1.Explore College Scorecard website - https://collegescorecard.ed.gov/
# #### 2.Explore College Scorecard Data web page - https://collegescorecard.ed.gov/data/
# #### 3.Download and read the documentation - https://collegescorecard.ed.gov/assets/FullDataDocumentation.pdf
# #### 4.Download the dataset - https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip (265MB Zip File)
# #### 5.Unzip the file into a folder in your personal computer (there are many files, one for each school year)
# #### 6.Upload the 2017-2018 school year file "MERGED2017_18_PP.csv" to Colab/Deepnote or any Cloud environment of your choice (you can use your local environment too) and create a Jupyter notebook to explore the dataset:
# - how many colleges or rows?
# - how many variables or columns?
# - Look at the first 5 colleges
# - look at the last 5 colleges
# - Look at a random sample of 5 colleges

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/MERGED2017_18_PP.csv')
print(df)
# Out:
#         UNITID    OPEID  OPEID6  \
# 0       100654   100200    1002
# 1       100663   105200    1052
# 2       100690  2503400   25034
# 3       100706   105500    1055
# 4       100724   100500    1005
# ...        ...      ...     ...
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 0                              Alabama A & M University           Normal
# 1                   University of Alabama at Birmingham       Birmingham
# 2                                    Amridge University       Montgomery
# 3                   University of Alabama in Huntsville       Huntsville
# 4                              Alabama State University       Montgomery
# ...                                                 ...              ...
# ...

# %% [markdown]
# ## how many colleges or rows?

# %%
print("Colleges or Rows: ", df.shape[0])
# Out:
# Colleges or Rows:  7112

# %% [markdown]
# ## Look at the first 5 colleges

# %%
df.head(5)
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# 3     AL       35899           NaN      NaN     NaN  ...
# 4     AL  36104-0271           NaN      NaN     NaN  ...
#
#    OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN   G12MN  \
# 0                           NaN       0.7106        0.7418   5207.0  1185.0
# ...

# %% [markdown]
# ## look at the last 5 colleges

# %%
df.tail(5)
# Out:
#         UNITID    OPEID  OPEID6  \
# 7107  48312404   108163    1081
# 7108  48387801  4223701   42237
# 7109  48400201  4228101   42281
# 7110  48778201  4221501   42215
# 7111  49005401  4182601   41826
#
#                                                  INSTNM             CITY  \
# 7107                   Arizona State University at Yuma             Yuma
# 7108  Bay Area Medical Academy - San Jose Satellite ...         San Jose
# 7109           High Desert Medical College - Bakerfield      Bakersfield
# 7110                                       BCI - Malden           Malden
# 7111               HCI College - Fort Lauderdale Campus  Fort Lauderdale
#
#      STABBR        ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 7107     AZ  853656900           NaN      NaN     NaN  ...
# 7108     CA      95113           NaN      NaN     NaN  ...
# 7109     CA      93301           NaN      NaN     NaN  ...
# 7110     MA  021480000           NaN      NaN     NaN  ...
# ...

# %% [markdown]
# ## Look at a random sample of 5 colleges

# %%
df.sample(5)
# Out:
#       UNITID    OPEID  OPEID6  \
# 5061  444565  3723300   37233
# 3993  245342  2599700   25997
# 1998  181145   849200    8492
# 3179  216782  2202300   22023
# 214   110422   114300    1143
#
#                                                  INSTNM             CITY  \
# 5061                             Culinary Institute Inc          Houston
# 3993                         Vatterott College-Berkeley         Berkeley
# 1998         CHI Health School of Radiologic Technology            Omaha
# 3179                        Pittsburgh Career Institute       Pittsburgh
# 214   California Polytechnic State University-San Lu...  San Luis Obispo
#
#      STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 5061     TX  77022-4322           NaN      NaN     NaN  ...
# 3993     MO       63134           NaN      NaN     NaN  ...
# 1998     NE       68122           NaN      NaN     NaN  ...
# 3179     PA  15219-1907           NaN      NaN     NaN  ...
# ...

# %% [markdown]
# ## 7.Since there are too many variables to explore, many of which are not interesting. Create a smaller data frame with the following 9 variables:
# - UNITID
# - INSTNM
# - CITY
# - STABBR
# - ZIP
# - ADM_RATE
# - UGDS
# - TUITIONFEE_IN
# - MN_EARN_WNE_P10

# %%
pd.set_option("display.max_columns", 20)
df2 = pd.DataFrame()
df2 = df.filter(['UNITID','INSTNM','CITY','STABBR','ZIP','ADM_RATE','UGDS','TUITIONFEE_IN','MN_EARN_WNE_P10'])
print(df2)
# Out:
#         UNITID                                             INSTNM  \
# 0       100654                           Alabama A & M University
# 1       100663                University of Alabama at Birmingham
# 2       100690                                 Amridge University
# 3       100706                University of Alabama in Huntsville
# 4       100724                           Alabama State University
# ...        ...                                                ...
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                  CITY STABBR         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  \
# 0              Normal     AL       35762    0.9027   4824.0         9857.0
# ...

# %% [markdown]
# # Definitions
# ## 1.UNITID:
# - Unit ID for institution and this will be unique for each and every university.
#
# ## 2.INSTNM:
# - It refers to the name of the Institution.
#
# ## 3.CITY:
# - This attribute refers to the city where the university is located.
#
# ## 4.STABBR:
# - This refers to the State postcode of the university.
#
# ## 5.ZIP:
# - This refers to the ZIP Code of the location the university located.
#
# ## 6.ADM_RATE:
# - This contains the Admission rate of the university.
#
# ## 7.UGDS
# - This contains Enrollment of undergraduate certificate/degree-seeking  students in the university.
#
# ## 8.TUITIONFEE_IN
# - It defines the In-state tuition and fees of the university.
#
# ## 9.MN_EARN_WNE_P10:
# - This holds the Mean earnings of students working and not enrolled 10 years after entry from the university.

# %% [markdown]
# ## Explore the smaller data frame

# %% [markdown]
# - 1.Look at the first 10 colleges

# %%
df2.head(10)
# Out:
#    UNITID                               INSTNM            CITY STABBR  \
# 0  100654             Alabama A & M University          Normal     AL
# 1  100663  University of Alabama at Birmingham      Birmingham     AL
# 2  100690                   Amridge University      Montgomery     AL
# 3  100706  University of Alabama in Huntsville      Huntsville     AL
# 4  100724             Alabama State University      Montgomery     AL
# 5  100751            The University of Alabama      Tuscaloosa     AL
# 6  100760    Central Alabama Community College  Alexander City     AL
# 7  100812              Athens State University          Athens     AL
# 8  100830      Auburn University at Montgomery      Montgomery     AL
# 9  100858                    Auburn University          Auburn     AL
#
#           ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 0       35762    0.9027   4824.0         9857.0              NaN
# 1  35294-0110    0.9181  12866.0         8328.0              NaN
# ...

# %% [markdown]
# ### 2. look at the last 10 colleges

# %%
df2.tail(10)
# Out:
#         UNITID                                             INSTNM  \
# 7102  48154401  National Personal Training Institute of Cleveland
# 7103  48305401             Barber School of Pittsburgh - Ambridge
# 7104  48312401                 Arizona State University at Tucson
# 7105  48312402  Arizona State University - ASU Colleges at Lak...
# 7106  48312403        Arizona State University at The Gila Valley
# 7107  48312404                   Arizona State University at Yuma
# 7108  48387801  Bay Area Medical Academy - San Jose Satellite ...
# 7109  48400201           High Desert Medical College - Bakerfield
# 7110  48778201                                       BCI - Malden
# 7111  49005401               HCI College - Fort Lauderdale Campus
#
#                   CITY STABBR        ZIP  ADM_RATE  UGDS  TUITIONFEE_IN  \
# 7102  Highland Heights     OH      44143       NaN   NaN            NaN
# 7103          Ambridge     PA  150030000       NaN   NaN            NaN
# ...

# %% [markdown]
# ###3. Look at a random sample of 10 colleges

# %%
df2.sample(10)
# Out:
#       UNITID                                             INSTNM  \
# 488   123679               Concorde Career College-Garden Grove
# 5206  447935                                        ATA College
# 1455  162061                      Capitol Technology University
# 405   120087                        North-West College-Van Nuys
# 1912  178183                                  Midwest Institute
# 2586  199908                 Western Piedmont Community College
# 5900  466189  National American University-Colorado Springs ...
# 5746  459985               Southern Careers Institute-Harlingen
# 6245  483364                       Delta College-Slidell Campus
# 4828  438735     Aviation Institute of Maintenance-Indianapolis
#
#                   CITY STABBR         ZIP  ADM_RATE    UGDS  TUITIONFEE_IN  \
# 488       Garden Grove     CA  92840-9201    0.8329   577.0            NaN
# 5206        Louisville     KY       40223       NaN   289.0        11545.0
# ...

# %% [markdown]
# ## Find and display UMBC

# %%
a = df2.loc[df2["INSTNM"].str.contains('University of Maryland-Baltimore County')]
print(a)
# Out:
#       UNITID                                   INSTNM       CITY STABBR  \
# 1478  163268  University of Maryland-Baltimore County  Baltimore     MD
#
#         ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1478  21250    0.6021  11130.0        11518.0              NaN

# %% [markdown]
# ## Find Univ. of Maryland College Park

# %%
b = df2.loc[df2["INSTNM"].str.contains('University of Maryland-College Park')]
print(b)
# Out:
#       UNITID                               INSTNM          CITY STABBR    ZIP  \
# 1479  163286  University of Maryland-College Park  College Park     MD  20742
#
#       ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1479     0.445  29273.0        10399.0              NaN

# %% [markdown]
# ## Find and display Loyola College Maryland

# %%
c = df2.loc[df2["INSTNM"].str.contains('Loyola University Maryland')]
print(c)
# Out:
#       UNITID                      INSTNM       CITY STABBR         ZIP  \
# 1475  163046  Loyola University Maryland  Baltimore     MD  21210-2699
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1475    0.7528  3903.0        47560.0              NaN

# %% [markdown]
# ## Find and display Johns Hopskins

# %%
d = df2.loc[df2["INSTNM"].str.contains('Johns Hopkins University')]
print(d)
# Out:
#       UNITID                    INSTNM       CITY STABBR         ZIP  \
# 1473  162928  Johns Hopkins University  Baltimore     MD  21218-2688
#
#       ADM_RATE    UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1473    0.1254  5663.0        52170.0              NaN

# %%
df4 = pd.DataFrame()
p= df4.append(a)
q = p.append(b)
r = q.append(c)
s = r.append(d)

print(s)
# Out:
#       UNITID                                   INSTNM          CITY STABBR  \
# 1478  163268  University of Maryland-Baltimore County     Baltimore     MD
# 1479  163286      University of Maryland-College Park  College Park     MD
# 1475  163046               Loyola University Maryland     Baltimore     MD
# 1473  162928                 Johns Hopkins University     Baltimore     MD
#
#              ZIP  ADM_RATE     UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# 1478       21250    0.6021  11130.0        11518.0              NaN
# 1479       20742    0.4450  29273.0        10399.0              NaN
# 1475  21210-2699    0.7528   3903.0        47560.0              NaN
# 1473  21218-2688    0.1254   5663.0        52170.0              NaN

# %% [markdown]
# ## Calculate the min, max, and average in-state tution of the above four institutions.

# %%
min_tution = s['TUITIONFEE_IN'].min()
print("Min Tuition: " ,min_tution)
# Out:
# Min Tuition:  10399.0

# %%
max_tution = s['TUITIONFEE_IN'].max()
print("Max Tuition:", max_tution)
# Out:
# Max Tuition: 52170.0

# %%
avg_tution = s['TUITIONFEE_IN'].mean()
print("Avg Tuition:", avg_tution)
# Out:
# Avg Tuition: 30411.75

# %% [markdown]
# ## 11. Filter the smaller dataset further to only keep colleges from Maryland,Virgina, Washington DC, Delaware, and Pennsylvinia.

# %%
df5 = pd.DataFrame()
a = df2.loc[df2["INSTNM"].str.contains('Maryland')]
b = df2.loc[df2["INSTNM"].str.contains('Washington DC')]
c = df2.loc[df2["INSTNM"].str.contains('Delaware')]
d = df2.loc[df2["INSTNM"].str.contains('Pennsylvinia')]
p = df5.append(a)
q = p.append(b)
r = q.append(c)
df5 = r.append(d)
print(df5)
# Out:
#         UNITID                                             INSTNM  \
# 1447    161688                       Allegany College of Maryland
# 1457    162122                       College of Southern Maryland
# 1472    162830                           Aveda Institute-Maryland
# 1475    163046                         Loyola University Maryland
# 1476    163204               University of Maryland Global Campus
# 1477    163259                   University of Maryland Baltimore
# 1478    163268            University of Maryland-Baltimore County
# 1479    163286                University of Maryland-College Park
# 1480    163295                  Maryland Institute College of Art
# 1481    163338               University of Maryland Eastern Shore
# 1489    163578                  Notre Dame of Maryland University
# 1493    163815                   Maryland Beauty Academy of Essex
# 1495    163912                     St. Mary's College of Maryland
# ...

# %% [markdown]
# ## Save the filtered dataset to a new file named "Five_States_Colleges.csv" for future analysis

# %%
df4.to_csv('Five_States_Colleges.csv',na_rep="NaN")
