# %% [markdown]
# <a href="https://colab.research.google.com/github/dkavali/data690_Dikshitha/blob/main/Individual_project_Part_B/Individual_Project_Part_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing libraries

import pandas as pd
import plotly
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio

# %%
pio.templates
# Out:
# Templates configuration
# -----------------------
#     Default template: 'plotly'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none']

# %%
pio.templates.default='plotly_dark'

# %%
#Reading data

df = pd.read_csv('https://raw.githubusercontent.com/dkavali/data690_Dikshitha/main/Individual_project_Part_B/wdi_data%20(5).csv')
df.head(10)
# Out:
#    Unnamed: 0  Year  ...  Income Group    Lending Type
# 0           0  2015  ...   High income  Not classified
# 1           1  2016  ...   High income  Not classified
# 2           2  2017  ...   High income  Not classified
# 3           3  2018  ...   High income  Not classified
# 4           4  2019  ...   High income  Not classified
# 5           5  2020  ...   High income  Not classified
# 6           6  2015  ...   High income  Not classified
# 7           7  2016  ...   High income  Not classified
# 8           8  2017  ...   High income  Not classified
# 9           9  2018  ...   High income  Not classified
#
# [10 rows x 9 columns]

# %%
#Dropping unwanted rows 

df_new = df.drop(columns=['Unnamed: 0'])
df_new.head()
# Out:
#    Year         value  ... Income Group    Lending Type
# 0  2015  7.506363e+11  ...  High income  Not classified
# 1  2016  7.949772e+11  ...  High income  Not classified
# 2  2017  8.427717e+11  ...  High income  Not classified
# 3  2018  7.740269e+11  ...  High income  Not classified
# 4  2019  8.342260e+11  ...  High income  Not classified
#
# [5 rows x 8 columns]

# %%
#Taking only particular data of 2020 year

df_2020 = df_new.query("Year == 2020")
df_2020.sample(10)
# Out:
#     Year         value  ...         Income Group    Lending Type
# 74  2020  7.126557e+01  ...          High income  Not classified
# 86  2020  2.585513e+02  ...  Upper middle income            IBRD
# 40  2020  9.213039e+01  ...          High income  Not classified
# 17  2020  3.158066e+13  ...  Upper middle income            IBRD
# 46  2020  6.148865e+01  ...          High income  Not classified
# 52  2020  2.145027e+02  ...  Upper middle income            IBRD
# 23  2020  1.945317e+12  ...  Lower middle income            IBRD
# 11  2020  1.010509e+12  ...          High income  Not classified
# 98  2020  9.432885e+01  ...          High income  Not classified
# 5   2020  1.226164e+12  ...          High income  Not classified
#
# [10 rows x 8 columns]

# %%
#Filtering only 2020 gdp data

df_2020_gdp = df_2020.query("indicator in['CM.MKT.TRAD.GD.ZS']")
df_2020_gdp
# Out:
#     Year       value  ...         Income Group    Lending Type
# 40  2020   92.130391  ...          High income  Not classified
# 46  2020   61.488648  ...          High income  Not classified
# 52  2020  214.502708  ...  Upper middle income            IBRD
# 58  2020   74.164285  ...  Lower middle income            IBRD
#
# [4 rows x 8 columns]

# %%
#Plotting bar graph of Stocks Traded- Total Value(% of GDP) in the year 2020


fig = px.bar(
    data_frame=df_2020_gdp,
    title="Stocks Traded- Total Value(% of GDP) in the year 2020",
    labels={"value":"Total Value(% of GDP)"},
    x="Country Name",
    y="value",
    color="Country Name"
)

fig.update_xaxes(categoryorder="total descending")


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="901c6fb4-1280-4c97-bc28-c360c12ada0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("901c6fb4-1280-4c97-bc28-c360c12ada0d")) {
#                     Plotly.newPlot(
#                         '901c6fb4-1280-4c97-bc28-c360c12ada0d',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>Total Value(% of GDP)=%{y}", "legendgroup": "Country Name=Australia", "marker": {"color": "#636efa"}, "name": "Country Name=Australia", "offsetgroup": "Country Name=Australia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Australia"], "xaxis": "x", "y": [92.1303905433], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>Total Value(% of GDP)=%{y}", "legendgroup": "Country Name=Canada", "marker": {"color": "#EF553B"}, "name": "Country Name=Canada", "offsetgroup": "Country Name=Canada", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Canada"], "xaxis": "x", "y": [61.48864822979999], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>Total Value(% of GDP)=%{y}", "legendgroup": "Country Name=China", "marker": {"color": "#00cc96"}, "name": "Country Name=China", "offsetgroup": "Country Name=China", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["China"], "xaxis": "x", "y": [214.5027076025], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Name=%{x}<br>Total Value(% of GDP)=%{y}", "legendgroup": "Country Name=India", "marker": {"color": "#ab63fa"}, "name": "Country Name=India", "offsetgroup": "Country Name=India", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["India"], "xaxis": "x", "y": [74.1642853238], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}] ...

# %%
#Stocks Traded Turnover ratio of domestic shares in the year 2020

df_2020_ds = df_2020.query("indicator in['CM.MKT.TRNR']")
df_2020_ds
# Out:
#     Year       value  ...         Income Group    Lending Type
# 74  2020   71.265573  ...          High income  Not classified
# 80  2020   38.255000  ...          High income  Not classified
# 86  2020  258.551270  ...  Upper middle income            IBRD
# 92  2020   74.950604  ...  Lower middle income            IBRD
# 98  2020   94.328850  ...          High income  Not classified
#
# [5 rows x 8 columns]

# %%
#Plotting the bar graph for the year 2020

fig = px.bar(
    data_frame=df_2020_ds,
    title="Stocks Traded Turnover ratio of domestic shares in the year 2020",
    labels={"value":"Domestic Share of Stocks", "Year":"YEAR"},
    x="Country Name",
    y="value",
    color="Country Code"
)

fig.update_xaxes(categoryorder="total descending")


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="67c1c38c-0350-43dd-a3ea-2a9129872507" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("67c1c38c-0350-43dd-a3ea-2a9129872507")) {
#                     Plotly.newPlot(
#                         '67c1c38c-0350-43dd-a3ea-2a9129872507',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Code=AUS<br>Country Name=%{x}<br>Domestic Share of Stocks=%{y}", "legendgroup": "Country Code=AUS", "marker": {"color": "#636efa"}, "name": "Country Code=AUS", "offsetgroup": "Country Code=AUS", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Australia"], "xaxis": "x", "y": [71.265572973], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Code=CAN<br>Country Name=%{x}<br>Domestic Share of Stocks=%{y}", "legendgroup": "Country Code=CAN", "marker": {"color": "#EF553B"}, "name": "Country Code=CAN", "offsetgroup": "Country Code=CAN", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Canada"], "xaxis": "x", "y": [38.255], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Code=CHN<br>Country Name=%{x}<br>Domestic Share of Stocks=%{y}", "legendgroup": "Country Code=CHN", "marker": {"color": "#00cc96"}, "name": "Country Code=CHN", "offsetgroup": "Country Code=CHN", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["China"], "xaxis": "x", "y": [258.5512703888], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Code=IND<br>Country Name=%{x}<br>Domestic Share of Stocks=%{y}", "legendgroup": "Country Code=IND", "marker": {"color": "#ab63fa"}, "name": "Country Code=IND", "offsetgroup": "Country Code=IND", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["India"], "xaxis": "x", "y": [74.9506041888], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country Code=JPN<br>Country Name=%{x}<br>Domestic Share of Stocks=%{y}", "legendgroup": "Country Code=JPN", "marker": {"color": "#FFA15A"}, "name": "Country Code=JPN", "offsetgroup": "Country Code=JPN", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Japan"], "xaxis": "x", "y": [94.32884952379999], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}] ...

# %%
#Stocks Traded Total Value(Current US Dollars) in the year 2020

df_2020_CR = df_2020.query("indicator in['CM.MKT.TRAD.CD']")
df_2020_CR
# Out:
#     Year         value  ...         Income Group    Lending Type
# 5   2020  1.226164e+12  ...          High income  Not classified
# 11  2020  1.010509e+12  ...          High income  Not classified
# 17  2020  3.158066e+13  ...  Upper middle income            IBRD
# 23  2020  1.945317e+12  ...  Lower middle income            IBRD
# 29  2020  6.337219e+12  ...          High income  Not classified
#
# [5 rows x 8 columns]

# %%
#Plotting pie graph for Stocks Traded Total Value(Current US Dollars) in the year 2020

fig = px.pie(
    df_2020_CR,
    values='value', 
    names='Country Name',
    title='Stocks Traded Total Value(Current US Dollars) in the year 2020',
    hover_name='Country Code',
)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2eb98fb4-2df1-4cc7-961c-fa4465496ae0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2eb98fb4-2df1-4cc7-961c-fa4465496ae0")) {
#                     Plotly.newPlot(
#                         '2eb98fb4-2df1-4cc7-961c-fa4465496ae0',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=%{label}<br>value=%{value}", "hovertext": ["AUS", "CAN", "CHN", "IND", "JPN"], "labels": ["Australia", "Canada", "China", "India", "Japan"], "legendgroup": "", "name": "", "showlegend": true, "textinfo": "percent+label", "textposition": "inside", "type": "pie", "values": [1226164220000.0, 1010509350000.0, 31580655980000.0, 1945317139001.35, 6337219210000.0]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{" ...

# %%
#Taking only particular data of 2015 year

df_2015 = df_new.query("Year == 2015")
df_2015.sample(10)
# Out:
#     Year         value  ...         Income Group    Lending Type
# 59  2015  1.269292e+02  ...          High income  Not classified
# 30  2015  4.139850e+13  ...          High income  Not classified
# 6   2015  1.096075e+12  ...          High income  Not classified
# 24  2015  5.571527e+12  ...          High income  Not classified
# 75  2015  6.880067e+01  ...          High income  Not classified
# 87  2015  4.596627e+01  ...  Lower middle income            IBRD
# 41  2015  7.041879e+01  ...          High income  Not classified
# 81  2015  4.802873e+02  ...  Upper middle income            IBRD
# 53  2015  3.813434e+01  ...  Lower middle income            IBRD
# 64  2015  2.269866e+02  ...          High income  Not classified
#
# [10 rows x 8 columns]

# %%
#Stocks Traded Turnover ratio of domestic shares in the year 2015

df_2015_ds = df_2015.query("indicator in['CM.MKT.TRNR']")
df_2015_ds
# Out:
#     Year       value  ...         Income Group    Lending Type
# 69  2015   63.233662  ...          High income  Not classified
# 75  2015   68.800668  ...          High income  Not classified
# 81  2015  480.287296  ...  Upper middle income            IBRD
# 87  2015   45.966272  ...  Lower middle income            IBRD
# 93  2015  113.822662  ...          High income  Not classified
# 99  2015  165.147847  ...          High income  Not classified
#
# [6 rows x 8 columns]

# %%
#Plotting pie graph for Stocks Traded Turnover ratio of domestic shares in the year 2015

fig = px.pie(
    df_2015_ds,
    values='value', 
    names='Country Name',
    title='Stocks Traded Turnover ratio of domestic shares in the year 2015',
    hover_name='Country Code',
)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="73f00581-fb32-434a-8f6e-8fbe314a7033" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("73f00581-fb32-434a-8f6e-8fbe314a7033")) {
#                     Plotly.newPlot(
#                         '73f00581-fb32-434a-8f6e-8fbe314a7033',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=%{label}<br>value=%{value}", "hovertext": ["AUS", "CAN", "CHN", "IND", "JPN", "USA"], "labels": ["Australia", "Canada", "China", "India", "Japan", "United States"], "legendgroup": "", "name": "", "showlegend": true, "textinfo": "percent+label", "textposition": "inside", "type": "pie", "values": [63.2336623007, 68.80066848279999, 480.2872960246, 45.9662724642, 113.82266209950001, 165.1478470986]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{" ...

# %%
#Stocks Traded- Total Value(% of GDP) in the year 2015

df_gdp_2015 = df_new.query("indicator == 'CM.MKT.TRAD.GD.ZS'")
df_gdp_2015.sample(10)
# Out:
#     Year       value  ...         Income Group    Lending Type
# 45  2019   82.256802  ...          High income  Not classified
# 61  2017  118.730024  ...          High income  Not classified
# 68  2019  108.206530  ...          High income  Not classified
# 48  2016  162.864849  ...  Upper middle income            IBRD
# 60  2016  106.250847  ...          High income  Not classified
# 37  2017   63.404982  ...          High income  Not classified
# 63  2019  100.646101  ...          High income  Not classified
# 52  2020  214.502708  ...  Upper middle income            IBRD
# 36  2016   65.763257  ...          High income  Not classified
# 54  2016   35.225108  ...  Lower middle income            IBRD
#
# [10 rows x 8 columns]

# %%
#Plotting pie graph for Stocks Traded- Total Value(% of GDP) in the year 2015

fig = px.pie(
    df_gdp_2015,
    values='value', 
    names='Country Name',
    title='Stocks Traded- Total Value(% of GDP) in the year 2015',
    hover_name='Country Code',
)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7e0dacb9-de83-4e5e-be8b-f4cdb3f1c9ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7e0dacb9-de83-4e5e-be8b-f4cdb3f1c9ff")) {
#                     Plotly.newPlot(
#                         '7e0dacb9-de83-4e5e-be8b-f4cdb3f1c9ff',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=%{label}<br>value=%{value}", "hovertext": ["AUS", "AUS", "AUS", "AUS", "AUS", "AUS", "CAN", "CAN", "CAN", "CAN", "CAN", "CAN", "CHN", "CHN", "CHN", "CHN", "CHN", "CHN", "IND", "IND", "IND", "IND", "IND", "IND", "JPN", "JPN", "JPN", "JPN", "JPN", "USA", "USA", "USA", "USA", "USA"], "labels": ["Australia", "Australia", "Australia", "Australia", "Australia", "Australia", "Canada", "Canada", "Canada", "Canada", "Canada", "Canada", "China", "China", "China", "China", "China", "China", "India", "India", "India", "India", "India", "India", "Japan", "Japan", "Japan", "Japan", "Japan", "United States", "United States", "United States", "United States", "United States"], "legendgroup": "", "name": "", "showlegend": true, "textinfo": "percent+label", "textposition": "inside", "type": "pie", "values": [55.5330088462, 65.7632569644, 63.4049820833, 54.0189182151, 59.7340486492, 92.1303905433, 70.4187935577, 75.4823719268, 77.619357104, 79.7776937629, 82.2568022289, 61.48864822979999, 355.51984704169996, 162.8648486527, 139.9086700325, 94.0684697065, 127.78560278450001, 214.5027076025, 38.1343360796, 35.225108237, 45.4392040159, 47.96955204, 44.786365789799994, 74.1642853238, 126.9292218261, 106.25084655719999, 118.7300244326, 127.2317126383, 100.64610080450001, 226.9866197971, 224.4393711847, 203.58145504549998, 160.2341766993, 108.20652989860001]}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{" ...

# %%
df_ind = df_new[df_new['Country Code']== 'IND']
df_ind
# Out:
#     Year         value  ...         Income Group Lending Type
# 18  2015  8.021892e+11  ...  Lower middle income         IBRD
# 19  2016  8.083451e+11  ...  Lower middle income         IBRD
# 20  2017  1.204808e+12  ...  Lower middle income         IBRD
# 21  2018  1.295711e+12  ...  Lower middle income         IBRD
# 22  2019  1.285594e+12  ...  Lower middle income         IBRD
# 23  2020  1.945317e+12  ...  Lower middle income         IBRD
# 53  2015  3.813434e+01  ...  Lower middle income         IBRD
# 54  2016  3.522511e+01  ...  Lower middle income         IBRD
# 55  2017  4.543920e+01  ...  Lower middle income         IBRD
# 56  2018  4.796955e+01  ...  Lower middle income         IBRD
# 57  2019  4.478637e+01  ...  Lower middle income         IBRD
# 58  2020  7.416429e+01  ...  Lower middle income         IBRD
# 87  2015  4.596627e+01  ...  Lower middle income         IBRD
# 88  2016  4.628908e+01  ...  Lower middle income         IBRD
# 89  2017  4.713668e+01  ...  Lower middle income         IBRD
# 90  2018  5.677191e+01  ...  Lower middle income         IBRD
# 91  2019  5.621499e+01  ...  Lower middle income         IBRD
# 92  2020  7.495060e+01  ...  Lower middle income         IBRD
#
# [18 rows x 8 columns]

# %%
# Stocks of India across the years
df_ind_stocks = df_ind.query("indicator in(['CM.MKT.TRNR','CM.MKT.TRAD.GD.ZS','CM.MKT.TRAD.CD'])")
df_ind_stocks
# Out:
#     Year         value  ...         Income Group Lending Type
# 18  2015  8.021892e+11  ...  Lower middle income         IBRD
# 19  2016  8.083451e+11  ...  Lower middle income         IBRD
# 20  2017  1.204808e+12  ...  Lower middle income         IBRD
# 21  2018  1.295711e+12  ...  Lower middle income         IBRD
# 22  2019  1.285594e+12  ...  Lower middle income         IBRD
# 23  2020  1.945317e+12  ...  Lower middle income         IBRD
# 53  2015  3.813434e+01  ...  Lower middle income         IBRD
# 54  2016  3.522511e+01  ...  Lower middle income         IBRD
# 55  2017  4.543920e+01  ...  Lower middle income         IBRD
# 56  2018  4.796955e+01  ...  Lower middle income         IBRD
# 57  2019  4.478637e+01  ...  Lower middle income         IBRD
# 58  2020  7.416429e+01  ...  Lower middle income         IBRD
# 87  2015  4.596627e+01  ...  Lower middle income         IBRD
# 88  2016  4.628908e+01  ...  Lower middle income         IBRD
# 89  2017  4.713668e+01  ...  Lower middle income         IBRD
# 90  2018  5.677191e+01  ...  Lower middle income         IBRD
# 91  2019  5.621499e+01  ...  Lower middle income         IBRD
# 92  2020  7.495060e+01  ...  Lower middle income         IBRD
#
# [18 rows x 8 columns]

# %%
df_pivot = df_ind_stocks.pivot(index =['Year','Country Code','Country Name','Region','Income Group','Lending Type'], columns ='indicator', values ='value').reset_index()
df_pivot
# Out:
# indicator  Year Country Code  ... CM.MKT.TRAD.GD.ZS CM.MKT.TRNR
# 0          2015          IND  ...         38.134336   45.966272
# 1          2016          IND  ...         35.225108   46.289084
# 2          2017          IND  ...         45.439204   47.136678
# 3          2018          IND  ...         47.969552   56.771908
# 4          2019          IND  ...         44.786366   56.214994
# 5          2020          IND  ...         74.164285   74.950604
#
# [6 rows x 9 columns]

# %%
fig = px.bar(
    df_pivot.dropna(),
    x = "Year",
    y = "CM.MKT.TRAD.CD",
    title = "Stocks",
    labels = {"Year":"Year","CM.MKT.TRAD.CD":"Stocks"},
    color = "Region",
    hover_name = "Country Name",
    text = "Country Name",
    
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9df6c2fd-cba1-4e0d-b6e3-adf7833a5fe0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9df6c2fd-cba1-4e0d-b6e3-adf7833a5fe0")) {
#                     Plotly.newPlot(
#                         '9df6c2fd-cba1-4e0d-b6e3-adf7833a5fe0',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Region=South Asia<br>Year=%{x}<br>Stocks=%{y}<br>Country Name=%{text}", "hovertext": ["India", "India", "India", "India", "India", "India"], "legendgroup": "Region=South Asia", "marker": {"color": "#636efa"}, "name": "Region=South Asia", "offsetgroup": "Region=South Asia", "orientation": "v", "showlegend": true, "text": ["India", "India", "India", "India", "India", "India"], "textposition": "auto", "type": "bar", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [802189246647.972, 808345072456.1079, 1204808201528.86, 1295711222296.8, 1285594464766.56, 1945317139001.35], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}] ...

# %%
df_pivot_all = df.pivot(index =['Year','Country Code','Country Name','Region','Income Group','Lending Type'], columns ='indicator', values ='value').reset_index()
df_pivot_all
# Out:
# indicator  Year Country Code  ... CM.MKT.TRAD.GD.ZS CM.MKT.TRNR
# 0          2015          AUS  ...         55.533009   63.233662
# 1          2015          CAN  ...         70.418794   68.800668
# 2          2015          CHN  ...        355.519847  480.287296
# 3          2015          IND  ...         38.134336   45.966272
# 4          2015          JPN  ...        126.929222  113.822662
# 5          2015          USA  ...        226.986620  165.147847
# 6          2016          AUS  ...         65.763257   59.784284
# 7          2016          CAN  ...         75.482372   57.552993
# 8          2016          CHN  ...        162.864849  249.907289
# 9          2016          IND  ...         35.225108   46.289084
# 10         2016          JPN  ...        106.250847  105.444196
# 11         2016          USA  ...        224.439371   94.718850
# 12         2017          AUS  ...         63.404982   53.644289
# 13         2017          CAN  ...         77.619357   54.083470
# 14         2017          CHN  ...        139.908670  197.713256
# 15         2017          IND  ...         45.439204   47.136678
# 16         2017          JPN  ...        118.730024   92.842927
# 17         2017          USA  ...        203.581455  116.078469
# 18         2018          AUS  ...         54.018918   61.294484
# 19         2018          CAN  ...         79.777694   70.883583
# 20         2018          CHN  ...         94.068470  206.654399
# 21         2018          IND  ...         47.969552   56.771908
# 22         2018          JPN  ...        127.231713  119.016616
# 23         2018          USA  ...        160.234177  108.512636
# 24         2019          AUS  ...         59.734049   56.078700
# 25         2019          CAN  ...         82.256802   59.464800
# 26         2019          CHN  ...        127.785603  214.288002
# 27         2019          IND  ...         44.786366   56.214994
# 28         2019          JPN  ...        100.646101   82.337900
# 29         2019          USA  ...        108.206530         NaN
# 30         2020          AUS  ...         92.130391   71.265573
# 31         2020          CAN  ...         61.488648   38.255000
# 32         2020          CHN  ...        214.502708  258.551270
# 33         2020          IND  ...         74.164285   74.950604
# 34         2020          JPN  ...               NaN   94.328850
#
# [35 rows x 9 columns]

# %%
fig = px.line(
    df_pivot_all, 
    x="Year", 
    y="CM.MKT.TRAD.CD",
    labels={"CM.MKT.TRAD.CD":"GDP per capita, PPP (current international $)"},
    hover_name='Country Name',
    color='Country Name'
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9699e22c-85e3-40e8-9cc4-51d5e229a55c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9699e22c-85e3-40e8-9cc4-51d5e229a55c")) {
#                     Plotly.newPlot(
#                         '9699e22c-85e3-40e8-9cc4-51d5e229a55c',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Australia<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "hovertext": ["Australia", "Australia", "Australia", "Australia", "Australia", "Australia"], "legendgroup": "Country Name=Australia", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Country Name=Australia", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [750636340000.0, 794977154799.654, 842771714903.792, 774026908423.875, 834226020000.0, 1226164220000.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Canada<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "hovertext": ["Canada", "Canada", "Canada", "Canada", "Canada", "Canada"], "legendgroup": "Country Name=Canada", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Country Name=Canada", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [1096074730000.0, 1153366674108.8, 1280149390000.0, 1373654878943.51, 1432565050000.0, 1010509350000.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=China<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "hovertext": ["China", "China", "China", "China", "China", "China"], "legendgroup": "Country Name=China", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "Country Name=China", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [39326016590000.0, 18295058830306.6, 17223330026369.8, 13070642237217.1, 18247704170000.0, 31580655980000.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=India<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "hovertext": ["India", "India", "India", "India", "India", "India"], "legendgroup": "Country Name=India", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "Country Name=India", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [802189246647.972, 808345072456.1079, 1204808201528.86, 1295711222296.8, 1285594464766.56, 1945317139001.35], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Japan<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "hovertext": ["Japan", "Japan", "Japan", "Japan", "Japan", "Japan"], "legendgroup": "Country Name=Japan", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "Country Name=Japan", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019, 2020], "xaxis": "x", "y": [5571527250000.0, 5230238447398.79, 5778429302687.51, 6304085320533.8, 5097597060000.0, 6337219210000.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=United States<br>Year=%{x}<br>GDP per capita, PPP (current international $)=%{y}", "hovertext": ["United States", "United States", "United States", "United States", "United States"], "legendgroup": "Country Name=United States", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "Country Name=United States", "showlegend": true, "type": "scatter", "x": [2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [41398501970000.0, 42071330000000.0, 39785881380000.0, 33027245670000.0, 23192148690000.0], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{

# %%
fig = px.scatter(
    df_pivot_all.dropna(),
    x="CM.MKT.TRAD.CD",
    y="CM.MKT.TRAD.GD.ZS",
    title="TOP Countries by Stocks Traded in the year 2015",
    labels={"CM.MKT.TRAD.CD":"Stocks Traded Total Value(Current US Dollars) in the year 2015","CM.MKT.TRAD.GD.ZS":"Stocks Traded- Total Value(% of GDP) in the year 2015"},
    color='Country Name',
    hover_name='Country Name',
    
    size_max=75,
    height =800
)
fig.update_layout(showlegend=False)
fig.update_traces(textposition="top center")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="907cf121-bfb2-4f11-94de-5c1a11a456a8" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("907cf121-bfb2-4f11-94de-5c1a11a456a8")) {
#                     Plotly.newPlot(
#                         '907cf121-bfb2-4f11-94de-5c1a11a456a8',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Australia<br>Stocks Traded Total Value(Current US Dollars) in the year 2015=%{x}<br>Stocks Traded- Total Value(% of GDP) in the year 2015=%{y}", "hovertext": ["Australia", "Australia", "Australia", "Australia", "Australia", "Australia"], "legendgroup": "Country Name=Australia", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Country Name=Australia", "showlegend": true, "textposition": "top center", "type": "scatter", "x": [750636340000.0, 794977154799.654, 842771714903.792, 774026908423.875, 834226020000.0, 1226164220000.0], "xaxis": "x", "y": [55.5330088462, 65.7632569644, 63.4049820833, 54.0189182151, 59.7340486492, 92.1303905433], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Canada<br>Stocks Traded Total Value(Current US Dollars) in the year 2015=%{x}<br>Stocks Traded- Total Value(% of GDP) in the year 2015=%{y}", "hovertext": ["Canada", "Canada", "Canada", "Canada", "Canada", "Canada"], "legendgroup": "Country Name=Canada", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Country Name=Canada", "showlegend": true, "textposition": "top center", "type": "scatter", "x": [1096074730000.0, 1153366674108.8, 1280149390000.0, 1373654878943.51, 1432565050000.0, 1010509350000.0], "xaxis": "x", "y": [70.4187935577, 75.4823719268, 77.619357104, 79.7776937629, 82.2568022289, 61.48864822979999], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=China<br>Stocks Traded Total Value(Current US Dollars) in the year 2015=%{x}<br>Stocks Traded- Total Value(% of GDP) in the year 2015=%{y}", "hovertext": ["China", "China", "China", "China", "China", "China"], "legendgroup": "Country Name=China", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "Country Name=China", "showlegend": true, "textposition": "top center", "type": "scatter", "x": [39326016590000.0, 18295058830306.6, 17223330026369.8, 13070642237217.1, 18247704170000.0, 31580655980000.0], "xaxis": "x", "y": [355.51984704169996, 162.8648486527, 139.9086700325, 94.0684697065, 127.78560278450001, 214.5027076025], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=India<br>Stocks Traded Total Value(Current US Dollars) in the year 2015=%{x}<br>Stocks Traded- Total Value(% of GDP) in the year 2015=%{y}", "hovertext": ["India", "India", "India", "India", "India", "India"], "legendgroup": "Country Name=India", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "Country Name=India", "showlegend": true, "textposition": "top center", "type": "scatter", "x": [802189246647.972, 808345072456.1079, 1204808201528.86, 1295711222296.8, 1285594464766.56, 1945317139001.35], "xaxis": "x", "y": [38.1343360796, 35.225108237, 45.4392040159, 47.96955204, 44.786365789799994, 74.1642853238], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=Japan<br>Stocks Traded Total Value(Current US Dollars) in the year 2015=%{x}<br>Stocks Traded- Total Value(% of GDP) in the year 2015=%{y}", "hovertext": ["Japan", "Japan", "Japan", "Japan", "Japan"], "legendgroup": "Country Name=Japan", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "Country Name=Japan", "showlegend": true, "textposition": "top center", "type": "scatter", "x": [5571527250000.0, 5230238447398.79, 5778429302687.51, 6304085320533.8, 5097597060000.0], "xaxis": "x", "y": [126.9292218261, 106.25084655719999, 118.7300244326, 127.2317126383, 100.64610080450001], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Country Name=United States<br>Stocks Traded Total Value(Current US Dollars) in the year 2015=%{x}<br>Stocks Traded- Total Val ...
#                         {"height": 800, "legend": {"tracegroupgap": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "his
